# %%
class Bank :
    def _init_(self):
        self.name = "" 
        self.AccNo = 142203016 
        self.type = "" 
        self.balance = 00.0
        self.base = 00
        self.city = ""
        self.phnum = 00 
        self.money = 00

    def createAccount(self) : 
        self.AccNo += 53  
        print("+---------------------------------------------------------------------+")
        print("|                        WELCOME TO COEP BANK                         |")
        print("+---------------------------------------------------------------------+")
        self.name = input("==> Enter Your Name : ")
        self.type = input("==> Enter type of Bank Account :")
        self.city = input("==> Enter your City : ")
        self.phnum = input("==> Enter your Phone Number :")
        self.base = int(input("==> Enter Initial amount you want to deposite :"))
        print("\n\n")
        print(" _____________________________________________________________________")
        print("|         CONGRATULATIONS YOUR ACCOUNT IS CREATED SUCESSFULLY         |")
        print("|_____________________________________________________________________|")
        print("\n\n")
        check = int(input("\n\nEnter 1 to check the details are vaild or not "))
        if check == 1 :
            print("\n YOUR INFORMATION \n\n")
            print("======================")
            print("NAME OF USER      ==> ", self.name)
            print("BANK ACCOUNT TYPE ==> ", self.type)
            print("USERS CITY        ==> ", self.city)
            print("PHONE NUMBER      ==> ", self.phnum) 
            print("ACCOUNT BALANCE   ==> ", self.base)  
            print("YOUR ACCOUNT NUMBER  ==> ", self.AccNo)
        if check != 1 :
            print("Your data is Sucessfully stored Thanks for Creating account in our bank ......")
        
    def BankDetails(self) :
        key = int(input("Enter your Account Number = "))
        if self.AccNo == key :
            print("+---------------------------------------------------------------------+")
            print("|                           USERS INFORMATION                         |")
            print("+---------------------------------------------------------------------+")
            print("NAME OF USER      ==> ", self.name)
            print("BANK ACCOUNT TYPE ==> ", self.type)
            print("USERS CITY        ==> ", self.city)
            print("PHONE NUMBER      ==> ", self.phnum)  
            print("ACCOUNT NUMBER    ==> ", self.AccNo)
            print("BANK BALANCE      ==> ", self.base)
        else :
            print("!!!!! SORRY \n YOU ENTERED WRONG ACCOUNT NUMBER .... ")

    def deposite(self) :
        key = int(input("Enter your Account Number = "))
        
        if self.AccNo == key :
            self.money = int(input("Enter the Amount you want to Deposite\nNOTE: Pls Enter Money Greater than 0 "))
            if self.money > 0 :
                self.base = self.money + self.base 
                print("\n\n")
                print(" _____________________________________________________________________")
                print("|                   YOUR MONEY CREDITED SUCESSFULLY                  |")
                print("|_____________________________________________________________________|")
                print("\n\n")
                print("\nBANK BALANCE SHEET")
                print("======================")
                print("CURRENT BALANCE  ==> ", self.base)
        else :
            print("!!!!! SORRY \n YOU ENTERED WRONG ACCOUNT NUMBER .... ")

    def withdraw(self) :
        key = int(input("Enter your Account Number = "))
        
        if self.AccNo == key :
            print("YOUR CURRENT BALANCE ==> ",self.base)
            money = int(input("Enter the Amount you want to withdraw\nNOTE : Pls Enter money greater than 0"))
            if money > 0 :
                self.base = self.base - self.money 
                print("\n\n")
                print(" _____________________________________________________________________")
                print("|                   YOUR MONEY DEBITED SUCESSFULLY                    |")
                print("|_____________________________________________________________________|")
                print("\n\n")
                print("\nBANK BALANCE SHEET ")
                print("======================")
                print("CURRENT BALANCE  ==> ", self.base)
            else :
                print("!!!!! SORRY \n YOU ENTERED WRONG ACCOUNT NUMBER .... ")

account = Bank() 
while True:
    print("\n")
    print("+---------------------------------------------------------------------+")
    print("|                        WELCOME TO COEP BANK                         |")
    print("+---------------------------------------------------------------------+")
    print(" 1 - Create Bank Account ")
    print(" 2 - Check Bank details ")
    print(" 3 - Deposite Money  ")
    print(" 4 - Withdraw Money ")
    print(" 5 - Exit ")

    choice = int(input("Enter choice: "))

    if choice == 1:
        account.createAccount()
    elif choice == 2:
        account.BankDetails()
    elif choice == 3:
        account.deposite()
    elif choice == 4:
        account.withdraw()
    elif choice == 5:
        exit()
    else:
        print("Invalid choice")
